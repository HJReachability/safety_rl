# %%
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
from utilsDCAnalytics import *

# %%
fig, ax = plt.subplots(1, 1, figsize=(6,6))
R=1.
R_turn=.6
r=.3
orientation=0
extent=np.array([-1., 1., -1., 1.])
#plot_outer_safety(R, R_turn, orientation, ax, extent)

plot_reach_avoid_type_1(R, R_turn, r, orientation, ax, extent)
# Out:
# 2.190720972135699
